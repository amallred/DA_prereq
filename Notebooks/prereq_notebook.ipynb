# %% [markdown]
# Howdy, my name is Amanda and I'm excited to learn how to tell stories with data to make a positive impact on the world. I just completed the Web Development pathway where I got to present my project during Demo Day and I hope to combine what I learned in both pathways here.

# %%
print("Hello, Code:You!")
# Out:
# Hello, Code:You!
